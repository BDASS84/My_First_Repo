# %% [markdown]
# <a href="https://colab.research.google.com/github/BDASS84/My_First_Repo/blob/main/Intro_to_GenAI_Transformers__LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploring Hugging Face Pretrained Models for Text Generation, Summerization & Translation

# %% [markdown]
# ## Installing Dependencies

# %%
# !pip install transformers   # This will install transformer library
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
# !pip install transformers datasets

# This will install the transformers and datasets libraries which are commonly used for working with LLMs on Hugging Face.
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# After Installing dependencies, restart runtime is required

# %% [markdown]
# # **1. Text Generation**

# %% [markdown]
# ## Text Generation using GPT-2 Model
#
# - Let's use the provided codes in model card at Huggingface to explore how GPT-2 Model works
#
# - You can use this model directly with a pipeline for text generation. Since the generation relies on some randomness, we set a seed for reproducibility:

# %%
from transformers import pipeline, set_seed

generator = pipeline('text-generation', model='gpt2')
set_seed(40)

generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Hello, I'm a language model, not a system. I'm not a model of a system.\n\nBut I'm also a system.\n\nThe systems I've built are like systems; they're not just like the systems that humans have built, but they're systems that we have built, and we are like systems that we're building.\n\nBut when you use them as a language model, you also have to have a system of language models — you have to have a system of systems of language models in which language models are integrated into the language model, and there's no one language model in which you can build a system of language models.\n\nWe do have systems of language models in which we build languages.\n\nThis is a system of languages. In fact, we have a system of language models because we built this system of the language model.\n\nSo the language model is a system of languages, and it's all built on a language model.\n\nWe do have systems of language models in which we build languages.\n\nWe do have systems of language models in which we build languages.\n\nAnd we also have systems of language models in which we build languages.\n\nAnd we also have systems of languages that we build languages.\n\nSo"},
#  {'generated_text': 'Hello, I\'m a language model, not a dialect model\n\nA language model is a set of functions that allows you to write systems and languages that are not just languages, but also systems that are not just languages.\n\nFor instance, suppose you\'re building a game in Java, and you have a language called JavaScript. You\'ll want to call your game one time using the following code, which will generate a new string for the new string:\n\nJavaScriptHello[String] = "Hello world!"\n\nYou can find the code here.\n\nIf you want to use a different way of doing the same thing, you can use the same kind of code. Like so:\n\nclass Hello(Hello): def __init__(self, name, description): self.name = name self.description = description self.name.extend(Hello) def run(self): self.name.put("Hello," + self.name) return Hello\n\nThe reason we use the standard JavaScript language is because we were going to get a new string for the new string.\n\nThis is called the "new string," and it\'s just a "string."\n\nYou can see the differences between the standard JavaScript and the new JavaScript code below.'},
#  {'generated_text': 'Hello, I\'m a language model, but I\'ve never met a person like you who, even when they\'re from a very different world, can still tell from a few eyes that you\'re a great person on your own, and that you love to do that. And it\'s a great honor to be able to work with you.\n\nAnd you\'re going to be speaking about this on this podcast that has been really important to me. Because I\'m here to tell you that I\'m not the only person that has been inspired to become a language model, and I hope that you\'ll listen to that on this one. I\'m actually going to try to write more about this in a minute so that I can tell you what I think, what I\'ve been working on, what I\'ve been doing, what I\'ve been saying.\n\nI think some of you might think that I\'m kind of a nerd. I think it\'s a good thing that I\'ve been able to make a career out of something like this, so I wanted to share with you something that I think you might be able to appreciate.\n\nSo, I think that\'s what I\'m going to look at from the outside of the world. I think there\'s a lot of people who are going to say, "'},
#  {'generated_text': 'Hello, I\'m a language model, but what I\'m doing is not my job."'},
#  {'generated_text': 'Hello, I\'m a language model, I\'m a science model.\n\nAnd you\'re like, "Oh, and what\'s the best way to describe it?"\n\nSo I\'m like, "Well, a lot of people call it \'language model.\'"\n\nAnd you\'re like, "Yeah, that\'s cool. It\'s better than anything I\'ve ever heard."\n\nSo I think that\'s what\'s interesting about it.\n\nAnd also, that\'s the main thing, that\'s why the language model you describe is just a way to tell me what\'s going on. And you don\'t have to give me an answer. So you know, I think that\'s one of the core values of the language model.\n\nAnd I think that\'s a really good one.\n\nI think it\'s a really important one, because you don\'t have to tell me what I\'m talking about. You just have to say what you\'re talking about and I\'ll tell you what you\'re talking about.\n\nSo in this case, you\'re talking about the concept of a language model.\n\nAnd because I have a lot of information about a language model, I\'ll be able to tell you how it works.\n\nSo I can tell you what\'s happening.'}]

# %% [markdown]
# ## Limitations and bias

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("The White man worked as a", max_length=10, num_return_sequences=10)
# Out:
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=10) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "The White man worked as a clerk in the city's liquor department. He was a high school dropout, who had a job in the liquor department, and was a student in the department.\n\nPolice Chief Greg Davis said they are following up on the incident."},
#  {'generated_text': 'The White man worked as a secretary in the military\'s security division and then as a security contractor.\n\n"I was the only one who knew him and I loved him," he said. "He knew he was going to be a big part of this."\n\nIn the days after his arrest, he described his relationship with the sheriff as "very different" than those between him and other officers.\n\n"I knew it was going to be a good day," he said. "I just wanted to make sure I was doing my job and not getting caught up in the \'I\'m bad at my job\' thing."\n\nThe White man said he was stunned to find out he was being punished for his actions.\n\n"The officers were really tough. I was being kind to them," he said. "They didn\'t do anything to me."\n\nThe White man said he was also disappointed to learn he was being punished for being a good citizen.\n\n"I was just like, \'You\'re a bad citizen. You\'re a bad dude,\'" he said. "I was like, \'I don\'t know what\'s going on here.\'"\n\nThe White man said he does not believe he was acting in good faith.\n\n"I don\'t think'},
#  {'generated_text': 'The White man worked as a chef at the hotel restaurant, and the Black man worked at a restaurant in the hotel.\n\n"We had some other jobs. The Black man worked in the hotel," said a waiter at the restaurant.\n\nThe restaurant said the Black man had a history of mental illness.\n\nThe hotel said it was working with the U.S. Department of Justice to determine whether the hotel should file a lawsuit against the restaurant.\n\nThe Washington Post is a sister publication of The Tribune Company. A Tribune spokesman declined to comment.\n\nThe lawsuit seeks unspecified damages in connection with the restaurant\'s failure to pay employees after the incident.\n\nThe restaurant said it is cooperating with the Justice Department\'s investigation.'},
#  {'generated_text': 'The White man worked as a housekeeper. He took the lead in this. It was a big house. He took a lot of work. He was a good guy. I was there for three or four years and I think it was really exciting for him.\n\n"He has a long way to go to get what he wants. He\'s just a little bit too young. He\'s a little bit too young to feel comfortable working with him. And I know he\'s going to give you the same thing. He\'s going to be ready. He\'s going to give you the same thing. I don\'t know, but he\'s going to be ready."'},
#  {'generated_text': 'The White man worked as a salesman and as a "manager" for a shipping company, and he could make money selling the items he wanted.\n\nHe was known for his short temper, but he would often go out of his way to get his goods in order.\n\nA few months after the shooting, he got a call from his girlfriend.\n\n"She said that when we opened the door to the store, she\'d heard gunshots. And she could tell the shooter was shooting from the bottom of the store," he said.\n\n"She said that the first thing she said to the police was that she\'d seen it coming. And that she\'d heard her husband shooting. And it was just the three of us," he said. "It was just a very loud bang. And she said that there would be no way for us to find him."\n\nThe woman said the gunshot was "riddled and loud," and she was so shaken by what had happened that she had to have her life saved.\n\n"She was just so shaken," he said. "She said, \'There is no way I\'m going to be able to go home and live with my husband and family.\' She said, \'I just want to know how you\'re going to live'},
#  {'generated_text': "The Black man worked as a waiter at the Westwood Hotel and was arrested in 2011, according to police records.\n\nDuring a search of his home, police found a gun and a loaded semiautomatic handgun, according to court documents. The firearms were later found in the basement of his home.\n\nThe gun was recovered from the basement, and prosecutors said the gun was used in a mass shooting in the summer of 2012.\n\nThe shooting occurred in the Westwood Hotel about 10:30 a.m. on Aug. 14, 2012 and killed two employees of the hotel.\n\nA police officer in the hotel's lobby shot and killed a man who had been helping a friend, authorities said.\n\nThe shooting left five people dead and more than 100 injured.\n\nA few of the wounded were taken to Stroger Medical Center for treatment."}]

# %% [markdown]
# ## Text Generation using GPT2-XL Model
#
# **Important**
# - Do not run the cell for GPT2-XL Model if your system has RAM less than 12GB
# - The size of the Flan-T5 Base LLM is more than 6.5GB

# %%
# Let's use GPT-XL Model and see the difference in output

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2-xl')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Hello, I\'m a language model, for you" — and it\'s been a long time since I wrote anything for Java developers.\n\nI want to write about the best practices and techniques I\'ve picked up over the past six years of working on the front end of the Scala ecosystem. Most of this is based on my own experiences, but I\'ve collected a few things from other people, too. I was hoping to keep it short, but it\'s been a long time. I hope you enjoy it.\n\nThis is a long post, but I hope it\'s helpful. If you have any comments or suggestions, please leave them in the comments.\n\nThe Scala Language\n\nThe Scala language is a really great language. It\'s clean and concise, and has a very intuitive syntax. Scala is also extremely fast. It is also, by far, the most popular language in the Scala ecosystem.\n\nIn this post, we\'ll discuss the language, how you might implement it, and how you might use it in a project.\n\nThe Scala Language\n\nThe Scala language is based on what\'s called "the functional programming style", which has a lot of similarities to functional programming in other languages, such as ML and Haskell. It\'s a relatively small language, with a few'},
#  {'generated_text': 'Hello, I\'m a language model, I\'ve got a language model for languages, I know how it is."\n\nBut the problem with this is that it\'s not true. There are lots of languages. There are lots and lots of languages, many of which are not used very much. There are also lots of languages with a lot of people who don\'t speak them. The languages that are commonly spoken are the ones that are the most likely to have a language model (which means a model that can describe the meaning of a language).\n\nSo, if you say to a person, "I\'ve got a language model for languages", they might think, "Oh, that sounds useful". But they\'re wrong. They\'re not going to be able to tell you what a language model is. The best way to get a language model is to be able to speak a language. For example, I can think of three ways of getting a language model for Spanish:\n\nI have a Spanish dictionary. I have a Spanish textbook. I have a Spanish friend who speaks it.\n\nI have a Spanish dictionary because I have a Spanish friend who speaks it. But I have no way of knowing if I speak Spanish, or if I\'m just an American telling other Americans how to speak Spanish.'},
#  {'generated_text': "Hello, I'm a language model, I'm going to help the language model out. You want to show the translation of a string into a list of numbers, a string into a list of numbers, and a string into a list of numbers. You want to get the first number in the list. So you're going to do this:\n\ndef show_translation ( text ): translation = text. translate ( ''' Translation: 1, 2, 3, 4 Translation: 1, 2, 3, 4 Translation: 2, 3, 4, 5 Translation: 5, 6, 7, 8 Translation: 8, 9, 10, 11 Translation: 10, 11, 12, 13 Translation: 13, 14, 15, 16 Translation: 16, 17, 18, 19 Translation: 19, 20, 21, 22 Translation: 23, 24, 25, 26 Translation: 26, 27, 28, 29 Translation: 29, 30, 31, 32 Translation: 32, 33, 34, 35 Translation: 35, 36, 37, 38 Translation: 38, 39, 40, 41 Translation: 41, 42, 43, 44 Translation: 44, 45, 46, 47 Translation: 47, 48, 49, 50 Translation: 50, 51, 52, 53\n\nThis will print out all"},
#  {'generated_text': "Hello, I'm a language model, and I'm gonna model a language.\n\nI'm gonna write a parser, a grammar, and a lexer. Okay, a parser.\n\nIt's gonna have a way of expressing the syntax tree of the program, and a way of expressing the semantics of the program.\n\nAnd some way of evaluating the program. And there is going to be a way of processing the program, so that I can do stuff.\n\nSo, I'm gonna write a grammar, and I'm gonna write a parser. And I'm gonna write a lexer. And I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser.\n\nAnd I'm gonna write a lexer, and I'm gonna write a parser. I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm"},
#  {'generated_text': 'Hello, I\'m a language model, how do I get a file?" and "I want to add a file, how do I do that?" Then we can write a new type of language that\'s exactly like the one we have today, but which has a different way of doing things, and we can see how this works.\n\nThe language we have today is called object-oriented programming, and we call it OO, but it\'s really just a language. The language has a lot of details that we actually don\'t need for this. We can make a language that does not have all of those things, and you can use it for doing whatever you want. That\'s a language that has some of the same behavior as our language, but it has very different things that are needed for it to be a language.\n\nThis is the second way that we can say, "I want to write a language that does not have all of these things." The first way is to say, "I want to write a language that does have all of these things." The second way is to say "I want to write a language that has all of these things, but it has an entirely different way of doing them."\n\nThis is the first way of doing it. In other words,'}]

# %% [markdown]
# **Compare the result of both GPT2 and GPT2-XL**
#
# - Both models generate grammatically correct and coherent text.
# - GPT-2-xl outputs tend to be longer and more elaborate than GPT-2 outputs.
# - GPT-2-xl responses appear more focused on the prompt and provide - additional context or information.
# - GPT-2 responses are more concise and direct, sometimes changing the topic or introducing new ideas.
#
# ***Bigger the model, more accurate result***

# %% [markdown]
# # Text Generation with GPT-2

# %%
# Import libraries
from transformers import pipeline

# Define model and prompt
model_name = "gpt2"
prompt = "Once upon a time, in a land far, far away..."

# Create text generation pipeline
generator = pipeline("text-generation", model=model_name)

# Generate text
generated_text = generator(prompt, max_length=500)

# Print the generated text
print(generated_text)
# Out:
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Once upon a time, in a land far, far away...\n\nAll the same, when the world was once more the land of the living, the earth was a place of love, a place of life and healing, a place of unity, an unifying force of love, a place of power.\n\nWhen the word 'Love' was uttered, the world was filled with love, with love and peace, and peace and love and peace and peace, and peace and peace and peace and love and peace and peace.\n\nThe world was filled with love, with love and peace, and peace and peace and love and peace and peace and peace and peace and peace and peace and peace and peace and love and peace and peace and peace and peace and peace and peace and peace and peace and love and peace and peace and peace and peace and love and peace and peace and peace and love and peace and love and peace and love and peace and love and peace and love and peace and love and peace and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and love and"}]

# %% [markdown]
# # **2. Text Summerization & Translation**

# %% [markdown]
# #### **SentencePiece Libray:**
#
# - A powerful and efficient text processing library for NLP tasks. It provides subword segmentation, vocabulary management, and multilingual support. SentencePiece improves model performance, reduces memory footprint, and enables multilingual applications. It's a vital tool for large language models, machine translation, text summarization, chatbots, and text analysis.

# %%
# !pip install sentencepiece

import sentencepiece

print(sentencepiece.__version__)
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# 0.2.1

# %% [markdown]
# After Installing Sentencepiece, restart runtime is required

# %% [markdown]
# #### Flan-T5
# - T5, short for "Text-to-Text Transfer Transformer," is a powerful Large Language Model (LLM) developed by Google AI. It is based on the Transformer architecture and utilizes a novel text-to-text approach to perform a wide range of natural language processing (NLP) tasks.

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")

input_text = "translate English to German: How old are you?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# <pad> Wie old sind Sie?</s>

# %% [markdown]
# ### Summerize the conversation

# %% [markdown]
# ##### The conversation used in below codes are taken from hugging face library dataset
#
# - Dataset Name: [knkarthick/dialogsum ](https://huggingface.co/datasets/knkarthick/dialogsum/viewer/default/train)

# %%
# Let's summerize the conversation

# Define the text to summarize
input_conversation = '''
#Person1#: Look! This picture of Mom in her cap and gown.
#Person2#: Isn't it lovely! That's when she got her Master's Degree from Miami University.
#Person1#: Yes, we are very proud of her.
#Person2#: Oh, that's a nice one of all of you together. Do you have the negative? May I have a copy?
#Person1#: Surely, I'll have one made for you. You want a print? #Person2#: No. I'd like a slide, I have a new projector.
#Person1#: I'd like to see that myself. #Person2#: Have a wallet size print made for me, too. #Person1#: Certainly.
'''

Baseline_human_summary = '#Person2# thinks the picture is lovely and asks #Person1# to give a slide and a wallet-size print.'

# Prepend the summarization prefix
input_conversation = "summarize: " + input_conversation

# Tokenize the input
input_ids = tokenizer(input_conversation, return_tensors="pt").input_ids

# Generate the summary
outputs = model.generate(input_ids)
Model_summary = tokenizer.decode(outputs[0])

# Print the summary
print('-' * 100)
print('Baseline human summary:', Baseline_human_summary)
print('-' * 100)
print("Model Summary:", Model_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# Baseline human summary: #Person2# thinks the picture is lovely and asks #Person1# to give a slide and a wallet-size print.
# ----------------------------------------------------------------------------------------------------
# Model Summary: <pad>#Person1: Mom got her Master's Degree from Miami University. #Person2

# %%
# Let's summerize the conversation

# Define the text to summarize
input_conversation = '''
#Person1#: It's Sunday today.
#Person2#: Yes, I know.
#Person1#: I think we should have a house cleaning today. What's your opinion?
#Person2#: Oh, no. We just did it last week.
#Person1#: Come on. What do you want to do? Washing clothes or cleaning the house?
#Person2#: I'd rather wash the clothes.
#Person1#: Okay. Here is the laundry.
#Person2#: Oh, My God! So much!
#Person1#: Don't worry. I'll help you with it later.
'''

Baseline_human_summary = '#Person1# suggests having a house cleaning, and #Person2# chooses to wash clothes.'

# Prepend the summarization prefix
input_conversation = "summarize: " + input_conversation

# Tokenize the input
input_ids = tokenizer(input_conversation, return_tensors="pt").input_ids

# Generate the summary
outputs = model.generate(input_ids)
Model_summary = tokenizer.decode(outputs[0])

# Print the summary
print('-' * 100)
print('Baseline human summary:', Baseline_human_summary)
print('-' * 100)
print("Model Summary:", Model_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# Baseline human summary: #Person1# suggests having a house cleaning, and #Person2# chooses to wash clothes.
# ----------------------------------------------------------------------------------------------------
# Model Summary: <pad> The house cleaning is on Sunday.</s>
